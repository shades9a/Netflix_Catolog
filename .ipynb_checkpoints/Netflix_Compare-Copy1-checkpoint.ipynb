# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy import stats

# Set up read of csv file
netflix_path = "netflix_template.csv"

netflix_info = pd.read_csv(netflix_path)

# testing to ensure csv was read
netflix_info.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country country.1  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil       NaN
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico       NaN
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore       NaN
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States       NaN
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States       NaN
#
#   country.2  YEAR_added  release_year rating   duration  \
# 0       NaN      2020.0          2020  TV-MA  4 Seasons
# 1       NaN      2016.0          2016  TV-MA     93 min
# ...

# %%
netflix_info_df = netflix_info.copy()

# %%
netflix_countries = netflix_info.loc[netflix_info["country"]=="United States"]
netflix_country_usa_df = pd.DataFrame(netflix_countries)
netflix_country_usa_df.head()
# Out:
#    show_id   type title        director  \
# 3       s4  Movie     9     Shane Acker
# 4       s5  Movie    21  Robert Luketic
# 7       s8  Movie   187  Kevin Reynolds
# 10     s11  Movie  1922    Zak Hilditch
# 14     s15  Movie  3022      John Suits
#
#                                                  cast        country  \
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 14  Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
#
#    country.1 country.2  YEAR_added  release_year rating duration  \
# 3        NaN       NaN      2017.0          2009  PG-13   80 min
# 4        NaN       NaN      2020.0          2008  PG-13  123 min
# 7        NaN       NaN      2019.0          1997      R  119 min
# ...

# %%
#find overall count of countries 
netflix_info_countries = netflix_info['country'].value_counts()

netflix_info_countries.head(10).index.tolist()
# Out:
# ['United States',
#  'India',
#  'United Kingdom',
#  'Canada',
#  'Japan',
#  'France',
#  'South Korea',
#  'Spain',
#  'Mexico',
#  'Australia']

# %%
country_top15 = netflix_info_countries.head(10).index.tolist()

country_top15
# Out:
# ['United States',
#  'India',
#  'United Kingdom',
#  'Canada',
#  'Japan',
#  'France',
#  'South Korea',
#  'Spain',
#  'Mexico',
#  'Australia']

# %%
netflix_info_df.loc[netflix_info_df['country'].isin(country_top15)]
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                                     7:19
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 7         s8    Movie                                      187
# 8         s9    Movie                                      706
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7783   s7784    Movie                                   Zubaan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
top15_byCntry_df = netflix_info_df.loc[netflix_info_df['country'].isin(country_top15)]
top15_byCntry_df
# Out:
#      show_id     type                                    title  \
# 1         s2    Movie                                     7:19
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 7         s8    Movie                                      187
# 8         s9    Movie                                      706
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7783   s7784    Movie                                   Zubaan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# ...

# %%
reduced_countries_df = top15_byCntry_df.loc[:, ["country", "TYPE1/listed_in", "YEAR_added"]]
reduced_countries_df
# Out:
#              country           TYPE1/listed_in  YEAR_added
# 1             Mexico                    Dramas      2016.0
# 3      United States        Action & Adventure      2017.0
# 4      United States                    Dramas      2020.0
# 7      United States                    Dramas      2019.0
# 8              India             Horror Movies      2019.0
# ...              ...                       ...         ...
# 7780           India                    Dramas      2018.0
# 7781   United States  Children & Family Movies      2020.0
# 7783           India                    Dramas      2019.0
# 7785       Australia    International TV Shows      2020.0
# 7786  United Kingdom             Documentaries      2020.0
#
# [5701 rows x 3 columns]

# %%
#find overall count of genres
genres_top15 = top15_byCntry_df.loc[:, ["country", "TYPE2", "TYPE1/listed_in", "TYPE3"]]

genres_top15_df = genres_top15 = top15_byCntry_df.loc[:, ["country", "TYPE2", "TYPE1/listed_in", "TYPE3"]]
genres_top15_df
# Out:
#              country                  TYPE2           TYPE1/listed_in  \
# 1             Mexico   International Movies                    Dramas
# 3      United States     Independent Movies        Action & Adventure
# 4      United States                    NaN                    Dramas
# 7      United States                    NaN                    Dramas
# 8              India   International Movies             Horror Movies
# ...              ...                    ...                       ...
# 7780           India     Independent Movies                    Dramas
# 7781   United States               Comedies  Children & Family Movies
# 7783           India   International Movies                    Dramas
# 7785       Australia             Reality TV    International TV Shows
# 7786  United Kingdom       Music & Musicals             Documentaries
#
#                       TYPE3
# 1                       NaN
# 3          Sci-Fi & Fantasy
# 4                       NaN
# ...

# %%
#reduced countries
# Out:
#           country     TYPE1/listed_in  YEAR_added
# 1          Mexico              Dramas      2016.0
# 3   United States  Action & Adventure      2017.0
# 4   United States              Dramas      2020.0
# 7   United States              Dramas      2019.0
# 8           India       Horror Movies      2019.0
# 9           India       Horror Movies      2017.0
# 10  United States              Dramas      2017.0
# 12         Mexico      Crime TV Shows      2019.0
# 14  United States  Independent Movies      2020.0
# 18          India            Comedies      2019.0

# %%
genres_top15_df.count()
# Out:
# country            5701
# TYPE2              4174
# TYPE1/listed_in    5701
# TYPE3              2210
# dtype: int64

# %%
# The value_counts method counts unique values in a column
count = genres_top15_df.value_counts()
count
# Out:
# country         TYPE2                  TYPE1/listed_in           TYPE3
# India            Dramas                Comedies                   International Movies    117
#                  Independent Movies    Dramas                     International Movies    106
# South Korea      Korean TV Shows       International TV Shows     Romantic TV Shows        63
# United States    Dramas                Comedies                   Independent Movies       62
# India            International Movies  Dramas                     Romantic Movies          59
#                                                                                          ...
# United Kingdom   Dramas                Action & Adventure         Independent Movies        1
#                                        Children & Family Movies   Independent Movies        1
#                                        Classic Movies             Romantic Movies           1
# ...

# %%
country_2014 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2014]
country_2014_df = pd.DataFrame(country_2014)
country_2014_df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR_added'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-210-cb5ae386a022> in <module>
# ...

# %%
country_2015 = reduced_countries_df.loc[reduced_countries_df["YEAR_added"]==2015]
country_2015_df = pd.DataFrame(country_2015)
country_2015_df.head()
# Out:
#     show_id   type                                   title        director  \
# 128    s129  Movie                                 6 Years   Hannah Fidell
# 247    s248  Movie                 A Very Murray Christmas   Sofia Coppola
# 316    s317  Movie                            Advantageous  Jennifer Phang
# 535    s536  Movie              Anjelah Johnson: Not Fancy       Jay Karas
# 551    s552  Movie  Anthony Jeselnik: Thoughts and Prayers      Adam Dubin
#
#                                                   cast        country  \
# 128  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
# 247  Bill Murray, Miley Cyrus, George Clooney, Chri...  United States
# 316  Jacqueline Kim, James Urbaniak, Freya Adams, K...  United States
# 535                              Anjelah Johnson-Reyes  United States
# 551                                   Anthony Jeselnik  United States
#
#     country.1 country.2  YEAR_added  release_year rating duration  \
# ...

# %%
country_2016 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2016]
country_2016_df = pd.DataFrame(country_2016)
country_2016_df.head()
# Out:
#    show_id   type            title                                director  \
# 1       s2  Movie             7:19                       Jorge Michel Grau
# 25     s26  Movie         (T)ERROR  Lyric R. Cabral, David Felix Sutcliffe
# 35     s36  Movie        #Rucker50                   Robert McCullough Jr.
# 59     s60  Movie  1000 Rupee Note                          Shrihari Sathe
# 62     s63  Movie       13 Cameras                          Victor Zarcoff
#
#                                                  cast        country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 25                                                NaN  United States
# 35                                                NaN  United States
# 59  Usha Naik, Sandeep Pathak, Shrikant Yadav, Gan...          India
# 62  PJ McCabe, Brianne Moncrief, Sarah Baldwin, Ji...  United States
#
#    country.1 country.2  YEAR_added  release_year rating duration  \
# ...

# %%
country_2017 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2017]
country_2017_df = pd.DataFrame(country_2017)
country_2017_df.head()
# Out:
#    show_id     type         title          director  \
# 3       s4    Movie             9       Shane Acker
# 5       s6  TV Show            46       Serdar Akar
# 9      s10    Movie          1920      Vikram Bhatt
# 10     s11    Movie          1922      Zak Hilditch
# 33     s34    Movie  #realityhigh  Fernando Lebrija
#
#                                                  cast        country  \
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 9   Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          India
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 33  Nesta Cooper, Kate Walsh, John Michael Higgins...  United States
#
#    country.1 country.2  YEAR_added  release_year rating  duration  \
# 3        NaN       NaN      2017.0          2009  PG-13    80 min
# 5        NaN       NaN      2017.0          2016  TV-MA  1 Season
# ...

# %%
country_2018 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2018]
country_2018_df = pd.DataFrame(country_2018)
country_2018_df.head()
# Out:
#    show_id   type                 title           director  \
# 19     s20  Movie                   '89                NaN
# 20     s21  Movie  ​​Kuch Bheege Alfaaz               Onir
# 21     s22  Movie          ​Goli Soda 2       Vijay Milton
# 22     s23  Movie    ​Maj Rati ​​Keteki  Santwana Bardoloi
# 23     s24  Movie           ​Mayurakshi        Atanu Ghosh
#
#                                                  cast         country  \
# 19                 Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 20  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...           India
# 21  Samuthirakani, Bharath Seeni, Vinoth, Esakki B...           India
# 22  Adil Hussain, Shakil Imtiaz, Mahendra Rabha, S...           India
# 23  Soumitra Chatterjee, Prasenjit Chatterjee, Ind...           India
#
#    country.1 country.2  YEAR_added  release_year rating duration  \
# 19       NaN       NaN      2018.0          2017  TV-PG   87 min
# ...

# %%
country_2019 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2019]
country_2019_df = pd.DataFrame(country_2019)
country_2019_df.head()
# Out:
#    show_id     type   title              director  \
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 15     s16    Movie   1-Oct        Kunle Afolayan
# 18     s19    Movie  15-Aug    Swapnaneel Jayakar
#
#                                                  cast        country  \
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 8   Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 12                                                NaN         Mexico
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...          India
#
#    country.1 country.2  YEAR_added  release_year rating  duration  \
# 7        NaN       NaN      2019.0          1997      R   119 min
# 8        NaN       NaN      2019.0          2019  TV-14   118 min
# ...

# %%
country_2020 = top15_byCntry_df.loc[reduced_countries_df["YEAR_added"]==2020]
country_2020_df = pd.DataFrame(country_2020)
country_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1680 entries, 0 to 7786
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          1680 non-null   object
#  1   type             1680 non-null   object
#  2   title            1680 non-null   object
#  3   director         1148 non-null   object
#  4   cast             1551 non-null   object
#  5   country          1680 non-null   object
#  6   country.1        246 non-null    object
#  7   country.2        86 non-null     object
#  8   YEAR_added       1680 non-null   float64
#  9   release_year     1680 non-null   int64
#  10  rating           1680 non-null   object
#  11  duration         1680 non-null   object
#  12  TYPE1/listed_in  1680 non-null   object
#  13  TYPE2            1298 non-null   object
#  14  TYPE3            673 non-null    object
#  15  description      1680 non-null   object
# dtypes: float64(1), int64(1), object(14)
# ...

# %%
renamed_Genres_df = top15_byCntry_df.rename(columns={"TYPE1/listed_in": "Genres"
                                                })
renamed_Genres_df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# 5         s6  TV Show                                       46
# ...      ...      ...                                      ...
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7783   s7784    Movie                                   Zubaan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#find way to do only top 15

#netflix_info_df.loc[netflix_info_df['country'].isin(country_top15)]

# %%
country_byGen =  top15_byCntry_df.groupby(["TYPE1/listed_in", "country"])
country_byGenre_df = pd.DataFrame(country_byGen.size())
country_byGenre_df
# Out:
#                                     0
# TYPE1/listed_in    country
# Action & Adventure Australia        7
#                    Brazil           3
#                    Canada          16
#                    China           23
#                    Egypt           14
# ...                                ..
# Thrillers          Australia        1
#                    Canada           2
#                    Spain            1
#                    United Kingdom   4
#                    United States   40
#
# [271 rows x 1 columns]

# %%
gen_byCntry = top15_byCntry_df.groupby(["country", "TYPE1/listed_in"])
gen_byCountry_df = pd.DataFrame(gen_byCntry.size()) 
gen_byCountry_df
# Out:
#                                           0
# country       TYPE1/listed_in
# Australia     Action & Adventure          7
#               British TV Shows            1
#               Children & Family Movies   12
#               Classic Movies              3
#               Comedies                    3
# ...                                     ...
# United States TV Comedies               100
#               TV Dramas                  52
#               TV Horror                   9
#               TV Shows                    3
#               Thrillers                  40
#
# [271 rows x 1 columns]

# %%
count_Cnty = top15_byCntry_df.count()

action = netflix_info.loc[netflix_info["TYPE1/listed_in"]=="Action & Adventure"]
actionType_df = pd.DataFrame(action)
actionType_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 721 entries, 3 to 7737
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          721 non-null    object
#  1   type             721 non-null    object
#  2   title            721 non-null    object
#  3   director         714 non-null    object
#  4   cast             715 non-null    object
#  5   country          706 non-null    object
#  6   country.1        180 non-null    object
#  7   country.2        58 non-null     object
#  8   YEAR_added       721 non-null    float64
#  9   release_year     721 non-null    int64
#  10  rating           721 non-null    object
#  11  duration         721 non-null    object
#  12  TYPE1/listed_in  721 non-null    object
#  13  TYPE2            622 non-null    object
#  14  TYPE3            394 non-null    object
#  15  description      721 non-null    object
# dtypes: float64(1), int64(1), object(14)
# ...

# %%
order = top15_byCntry_df.rating.unique()
count_movies = top15_byCntry_df.groupby('rating')['title'].count().reset_index()
count_shows = top15_byCntry_df.groupby('TYPE1/listed_in')['title'].count().reset_index()
count_shows = count_shows.append([{"rating" : "NC-17", "title" : 0},{"rating" : "PG-13", "title" : 0},{"rating" : "UR", "title" : 0}], ignore_index=True)
count_shows.sort_values(by="rating", ascending=True)
plt.figure(figsize=(13,7))
plt.title('Amount of Content by Rating (Movies vs TV Shows)')
plt.bar(count_movies.rating, count_movies.title)
plt.bar(count_movies.rating, count_shows.title, bottom=count_movies.title)
plt.legend(['TV Shows', 'Movies'])
plt.show()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
top15_byCntry_df.groupby('TYPE1/listed_in').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
import seaborn as sns 
top15 = top15_byCntry_df.set_index('TYPE1/listed_in').country.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
#top15 = renamed_Genres_df[reduced_countries_df != 'Country Unavailable']
plt.figure(figsize=(13,7))
g = sns.countplot(y = top15_byCntry_df, order=reduced_countries_df.value_counts().index[:15])
plt.title('Top 15 Countries Contributor on Netflix')
plt.xlabel('TYPE1/listed_in')
plt.ylabel('Country')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-5cd427f5e641> in <module>
#       3 #top15 = renamed_Genres_df[reduced_countries_df != 'Country Unavailable']
#       4 plt.figure(figsize=(13,7))
# ----> 5 g = sns.countplot(y = top15_byCntry_df, order=reduced_countries_df.value_counts().index[:15])
#       6 plt.title('Top 15 Countries Contributor on Netflix')
#       7 plt.xlabel('TYPE1/listed_in')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
# ...

# %%
top15_byCntry_df.loc[:, ["country", "TYPE1/listed_in", "YEAR_added"]].set_index('title').listed_in.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
plt.figure(figsize=(10,10))
g = sns.countplot(y = renamed_Genres, order=renamed_Genres.value_counts().index[:20])
plt.title('Top 20 Genres on Netflix')
plt.xlabel('Titles')
plt.ylabel('Genres')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-4656f92b823f> in <module>
# ----> 1 top15_byCntry_df.loc[:, ["country", "TYPE1/listed_in", "YEAR_added"]].set_index('title').listed_in.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
#       2 plt.figure(figsize=(10,10))
#       3 g = sns.countplot(y = renamed_Genres, order=renamed_Genres.value_counts().index[:20])
#       4 plt.title('Top 20 Genres on Netflix')
#       5 plt.xlabel('Titles')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['title'] are in the columns"

# %%
netflix_tvshows = netflix_info.loc[netflix_info["type"]=="TV Show"]
netflix_tvshows_df = pd.DataFrame(netflix_tvshows)
netflix_tvshows_df.head()
# Out:
#    show_id     type  title              director  \
# 0       s1  TV Show     3%                   NaN
# 5       s6  TV Show     46           Serdar Akar
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
# 16     s17  TV Show  9-Feb                   NaN
#
#                                                  cast country       country.1  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil             NaN
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey             NaN
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland   United States
# 12                                                NaN  Mexico             NaN
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...     NaN             NaN
#
#    country.2  YEAR_added  release_year rating   duration  \
# 0        NaN      2020.0          2020  TV-MA  4 Seasons
# 5        NaN      2017.0          2016  TV-MA   1 Season
# ...

# %%
netflix_info_countries_df = pd.DataFrame(netflix_info_countries)
netflix_info_countries_df.head(20)
# Out:
#                 country
# United States      2883
# India               956
# United Kingdom      577
# Canada              259
# Japan               237
# France              196
# South Korea         194
# Spain               168
# Mexico              123
# Australia           108
# Turkey              106
# Egypt               105
# Germany              92
# China                86
# Taiwan               82
# Brazil               79
# Hong Kong            77
# Indonesia            76
# Philippines          75
# Nigeria              71

# %%
# The value_counts method counts unique values in a column
count = reduced_countries_df["TYPE1/listed_in"].value_counts()
count
# Out:
# Dramas                          1384
# Comedies                        1074
# Documentaries                    751
# Action & Adventure               721
# International TV Shows           690
# Children & Family Movies         502
# Crime TV Shows                   369
# Kids' TV                         359
# Stand-Up Comedy                  321
# Horror Movies                    244
# British TV Shows                 232
# Docuseries                       194
# Anime Series                     148
# International Movies             114
# TV Comedies                      110
# Reality TV                       102
# Classic Movies                    77
# TV Dramas                         62
# Movies                            56
# Thrillers                         49
# TV Action & Adventure             37
# Stand-Up Comedy & Talk Shows      33
# Romantic TV Shows                 28
# Classic & Cult TV                 21
# Independent Movies                20
# ...
